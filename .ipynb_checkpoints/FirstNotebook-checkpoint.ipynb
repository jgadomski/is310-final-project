# %%
import requests
import pandas as pd

# %%
api_key = '4ccce73ee15bd2286749d9dad0c9e39e'

# %%
##import kaggle 
##coming back to this

# %%
df = pd.read_csv('ramen-ratings.csv')
df.head()
# Out:
#    Review #           Brand  \
# 0      2580       New Touch
# 1      2579        Just Way
# 2      2578          Nissin
# 3      2577         Wei Lih
# 4      2576  Ching's Secret
#
#                                              Variety Style Country Stars  \
# 0                          T's Restaurant Tantanmen    Cup   Japan  3.75
# 1  Noodles Spicy Hot Sesame Spicy Hot Sesame Guan...  Pack  Taiwan     1
# 2                      Cup Noodles Chicken Vegetable   Cup     USA  2.25
# 3                      GGE Ramen Snack Tomato Flavor  Pack  Taiwan  2.75
# 4                                    Singapore Curry  Pack   India  3.75
#
#   Top Ten
# 0     NaN
# 1     NaN
# 2     NaN
# 3     NaN
# 4     NaN

# %%
new_df = df[(df['Country']=='Japan')&(new_df['Stars']>='4')]
new_df.head(10)
# Out:
#     Review #          Brand                              Variety Style  \
# 6       2574        Acecook  Spice Deli Tantan Men With Cilantro   Cup
# 13      2567         Nissin         Deka Buto Kimchi Pork Flavor  Bowl
# 27      2553         Nissin   Hakata Ramen Noodle White Tonkotsu  Bowl
# 46      2534       Fujiwara        Hokkaido Hakodate Shoyu Ramen  Pack
# 48      2532         Nissin                Nippon Onomichi Ramen  Bowl
# 51      2529       Maruchan              Gotsumori Chanpon Ramen  Bowl
# 58      2522       Takamori     Hearty Japanese Style Curry Udon  Pack
# 62      2518  Samurai Ramen                          Umami Ramen  Pack
# 63      2517    Ikeda Shoku               Nabeyaki Tempura Udoin  Bowl
# 66      2514      Ogasawara            Kirin Giraffe Shoyu Ramen  Pack
#
#    Country Stars Top Ten
# 6    Japan     4     NaN
# 13   Japan   4.5     NaN
# 27   Japan  4.75     NaN
# 46   Japan     4     NaN
# 48   Japan  4.75     NaN
# 51   Japan   4.5     NaN
# ...

# %%
new_df['Stars'].hist(Color='Red')
